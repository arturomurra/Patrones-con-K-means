# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %% [markdown]
# # Descripcion de variables

# %% [markdown]
# Pregnancies (Cantidad de embarazos) variable cunatitativa discreta, rango (0:17)
# Glucose (Nivel de Glucosa en la sangre) variable cuantitativa discreta, rango (0:199)
# BloodPressure (Presion sanguinea) variable cuantitative discreta, rango (0:122)
#
# SkinThickness (Grossor de la piel) variable cuantitativa discreta, rango (0:99)
#
# Insulin (Nivel de Insulina) variable cuantitativa discreta, rango (0:846)
#
# BMI (Indice de masa corporal) variable cuantitativa discreta, rango(0:67.1)
#
# DiabetesPedigreeFunction (Indice de probabilidad de tener diabetes) variable cuantitativa continua, rango (0.078:2.42)
#
# Age (Edad) variable cuantitativa continua, rango (21:81)
# Outcome (0=No; 1=Yes) variable cualitativa ordinal

# %%
diabetes=pd.read_csv("diabetes.csv")

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %% [markdown]
# ## Exploracion de datos

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Variables cuantitativas

# %% [markdown]
# ### Medidas de tendencia central
# ### Embarazos

# %%
mean_pregnancies = diabetes['Pregnancies'].mean()
median_pregnancies =diabetes['Pregnancies'].median()
mode_pregnancies = diabetes['Pregnancies'].mode()
print("mean_pregnancies",mean_pregnancies)
print("median_pregnancies",median_pregnancies)
print("mode_pregnancies",mode_pregnancies)
# Out:
# mean_pregnancies 3.8450520833333335
# median_pregnancies 3.0
# mode_pregnancies 0    1
# dtype: int64

# %% [markdown]
# Conclusiones: La cantidad promedio de embarazos es de 3.8. El embarazo al centro es de 3 y la cantidad de embarzos mas repetida fue de 1

# %% [markdown]
# ### Glucosa

# %%
mean_glucose = diabetes['Glucose'].mean()
median_glucose =diabetes['Glucose'].median()
mode_glucose = diabetes['Glucose'].mode()
print("mean_glucose",mean_glucose)
print("median_glucose",median_glucose)
print("mode_glucose",mode_glucose)
# Out:
# mean_glucose 120.89453125
# median_glucose 117.0
# mode_glucose 0     99
# 1    100
# dtype: int64

# %% [markdown]
# Conclusiones: El valor promedio de la glucosa es de 120. El valor al centro de la glucosa es de 117 y existen 2 modas en la glucosa, una de 99 y otra de 100.

# %% [markdown]
# ### Presion Sanguinea

# %%
mean_bloodpressure = diabetes['BloodPressure'].mean()
median_bloodpressure =diabetes['BloodPressure'].median()
mode_bloodpressure = diabetes['BloodPressure'].mode()
print("mean_bloodpressure",mean_bloodpressure)
print("median_bloodpressure",median_bloodpressure)
print("mode_bloodpressure",mode_bloodpressure)
# Out:
# mean_bloodpressure 69.10546875
# median_bloodpressure 72.0
# mode_bloodpressure 0    70
# dtype: int64

# %% [markdown]
# Conclusiones: La presion sanguinea promedio es de 69. El valor al centro de la presion sanguinea es e 72 y la moda de la presion sanguinea es de 70.

# %% [markdown]
# ### Grosor de la piel

# %%
mean_skinthickness = diabetes['SkinThickness'].mean()
median_skinthickness =diabetes['SkinThickness'].median()
mode_skinthickness = diabetes['SkinThickness'].mode()
print("mean_skinthickness",mean_skinthickness)
print("median_skinthickness",median_skinthickness)
print("mode_skinthickness",mode_skinthickness)
# Out:
# mean_skinthickness 20.536458333333332
# median_skinthickness 23.0
# mode_skinthickness 0    0
# dtype: int64

# %% [markdown]
# Conclusiones: El promedio del grosor de la piel es de 20. El valor al centro del grosor de la piel es de 23 y la moda del grosor de la piel es 0, debido a que no se puede tener un valor de cero como grosor de la piel, al momento de generar la tabla de datos a los pacientes que no se les tomo el grosor, se incluyo el valor de 0.

# %% [markdown]
# ### Insulina

# %%
mean_insulin = diabetes['Insulin'].mean()
median_insulin =diabetes['Insulin'].median()
mode_insulin = diabetes['Insulin'].mode()
print("mean_insulin",mean_insulin)
print("median_insulin",median_insulin)
print("mode_insulin",mode_insulin)
# Out:
# mean_insulin 79.79947916666667
# median_insulin 30.5
# mode_insulin 0    0
# dtype: int64

# %% [markdown]
# Conclusiones: El promedio de la insulina esde 80. El valor al centro es de 30.5 y la moda de la insulina es de 0, como esto no es posible, no se tomara en cuenta este valor.

# %% [markdown]
# ### Indice de Masa Corporal

# %%
mean_bmi = diabetes['BMI'].mean()
median_bmi =diabetes['BMI'].median()
mode_bmi = diabetes['BMI'].mode()
print("mean_bmi",mean_bmi)
print("median_bmi",median_bmi)
print("mode_bmi",mode_bmi)
# Out:
# mean_bmi 31.992578124999977
# median_bmi 32.0
# mode_bmi 0    32.0
# dtype: float64

# %% [markdown]
# Conclusiones: El promedio del indice de masa corporal es de 32, el valor al centro es de 32 y la moda igualmente es de 32.

# %% [markdown]
# ### DiabetesPedigreeFunction

# %%
mean_diabetes = diabetes['DiabetesPedigreeFunction'].mean()
median_diabetes =diabetes['DiabetesPedigreeFunction'].median()
mode_diabetes = diabetes['DiabetesPedigreeFunction'].mode()
print("mean_diabetes",mean_diabetes)
print("median_diabetes",median_diabetes)
print("mode_diabetes",mode_diabetes)
# Out:
# mean_diabetes 0.4718763020833327
# median_diabetes 0.3725
# mode_diabetes 0    0.254
# 1    0.258
# dtype: float64

# %% [markdown]
# ### Edad

# %%
mean_age = diabetes['Age'].mean()
median_age =diabetes['Age'].median()
mode_age = diabetes['Age'].mode()
print("mean_age",mean_age)
print("median_age",median_age)
print("mode_age",mode_age)
# Out:
# mean_age 33.240885416666664
# median_age 29.0
# mode_age 0    22
# dtype: int64

# %% [markdown]
# Conclusiones: El promedio de la edad es de 33, el valor al centro de la edad es de 29 y la moda es de 22 años.

# %% [markdown]
# # Variables Categoricas

# %%
diabetes.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# # Visualización de datos

# %% [markdown]
# ### Variables Categóricas

# %%
import matplotlib.pyplot as plt       
fig = plt.figure(figsize=(18,6))

diabetes.Outcome.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
plotData=diabetes.Outcome.value_counts()
plotData.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Outcome'>

# %% [markdown]
# ### Variables Cuantitativas

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.displot(diabetes['Age'], bins=10)
plt.show()

# %%
diabetes.hist(bins=10,figsize=(9,7),grid=False);

# %%
ax = sns.boxplot(x="Outcome", y="Age", 
                data=diabetes)

ax = sns.stripplot(x="Outcome", y="Age",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
correlation_matrix = diabetes.corr().round(2)

# %%
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr=diabetes.corr()#["Survived"]
plt.figure(figsize=(10, 10))

sns.heatmap(corr, vmax=.8, linewidths=0.01,
            square=True,annot=True,cmap='YlGnBu',linecolor="white")
plt.title('Correlation between features');

# %% [markdown]
# ¿Hay alguna variable que no aporta información? Skin Thickness aporta información pero no importante.
#
# Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué?  Sería skin thickness porque en general la tabla trata sobre el riesgo de diabetes en señoras embarazadas y la verdad skin thickness no esta aportando nada importante.
#
# ¿Existen variables que tengan datos extraños?  Todas tienen en algún lugar, un dato con magnitud fuera de lo normal o íncluso la variable Outcome solo utiliza dos números, supongo que significan positivo y negativo o si y no, algo por el estilo.
#
# Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte? No están en rangos similares y no creo que afecte porque cada variable contiene datos diferentes, entonces es normal que tengan diferentes rangos.
#
# ¿Puedes encontrar grupos qué se parezcan? ¿Qué grupos son estos? Se pueden encontrar grupos similares, un ejemplo es sobre la funcion de deteccion de diabetes dependiendo de la historia familiar y el nivel de insulina.

# %%
diabetes_prep=diabetes.drop(['SkinThickness','Outcome'],axis=1)

# %%
diabetes_prep.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0            6      148             72        0  33.6
# 1            1       85             66        0  26.6
# 2            8      183             64        0  23.3
# 3            1       89             66       94  28.1
# 4            0      137             40      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
version1=diabetes_prep.loc[:,["Glucose","Insulin"]]
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)
kmeans.fit(version1)
labels = kmeans.predict(version1)

#gráqfica
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(diabetes_prep['Glucose'], diabetes_prep['Insulin'], c = labels)
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.show()

# %%
df = pd.DataFrame({'labels':labels, 'Outcome':diabetes['Outcome']})
crosstab = pd.crosstab(df['labels'],df['Outcome'])
crosstab
# Out:
# Outcome    0    1
# labels
# 0        423  183
# 1         77   85

# %%
iner_list = np.empty(10)
for i in range(1,10):
    kmeans2 = KMeans(n_clusters=i)
    kmeans2.fit(version1)
    iner_list[i] = kmeans2.inertia_

# iner_list = iner_list%100
# show the best number in graph
plt.plot(range(0,10), iner_list,'-')
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()

# %%
# Seleccionar dos variables y ver cómo se agrupan
datos1 = diabetes_prep.loc[:, ['Glucose', 'Insulin']]
# KMEANS 2
from sklearn.cluster import KMeans
kmeans2 = KMeans(n_clusters=3)
kmeans2.fit(datos1)
labels2 = kmeans2.predict(datos1)
list_clusters = np.unique(labels2)
print("Número de clusters:",len(list_clusters))
print("Cluster Centers:",kmeans2.cluster_centers_)


# visualization
plt.scatter(diabetes_prep['Glucose'], diabetes_prep['Insulin'], c = labels2)
plt.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 1], c='red', marker='x')
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.title('Glucose VS Insulin')
plt.show()
# Out:
# Número de clusters: 3
# Cluster Centers: [[114.00404858  14.25303644]
#  [158.44736842 441.28947368]
#  [129.27118644 158.79661017]]

# %%
#KMeans usando todas las dimensiones
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, max_iter=600) 
kmeans.fit(diabetes_prep)
# Out:
# KMeans(max_iter=600, n_clusters=2)

# %%
# Obtener las etiquetas de cluster asignadas a cada registro
labels = kmeans.labels_
# Ver el número total de etiquetas diferentes (Equivale a Número de clusters encontrados)
num_clusters = np.unique(labels)
print("Etiquetas de clusters:",num_clusters)
print("Total de Registros:",len(kmeans.labels_))
print("Centroides:", kmeans.cluster_centers_)
print("Total de variables que forman parte de un centroide:",len(kmeans.cluster_centers_[0]))
# Out:
# Etiquetas de clusters: [0 1]
# Total de Registros: 768
# Centroides: [[  3.64814815 141.46296296  72.56790123 255.78395062  34.88518519
#     0.59504938  33.67283951]
#  [  3.89768977 115.3960396   68.17986799  32.75412541  31.21930693
#     0.43894884  33.12541254]]
# Total de variables que forman parte de un centroide: 7

# %%
#Agregar información Survive así como las etiquetas del cluster a un dataset nuevo 
diabetes_nuevo=diabetes_prep.copy()

diabetes_nuevo.loc[:,'Outcome'] = diabetes['Outcome']
diabetes_nuevo.loc[:,'cluster'] = labels

diabetes_nuevo
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0              6      148             72        0  33.6
# 1              1       85             66        0  26.6
# 2              8      183             64        0  23.3
# 3              1       89             66       94  28.1
# 4              0      137             40      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             76      180  32.9
# 764            2      122             70        0  36.8
# 765            5      121             72      112  26.2
# 766            1      126             60        0  30.1
# 767            1       93             70        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  cluster
# 0                       0.627   50        1        1
# 1                       0.351   31        0        1
# 2                       0.672   32        1        1
# 3                       0.167   21        0        1
# ...

# %%
diabetes_nuevo.groupby("cluster").hist()
# Out:
# cluster
# 0    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object

# %%
sns.set_style('whitegrid')
sns.lmplot(x='Glucose',y='Insulin',data=diabetes_nuevo, hue='Outcome',
           palette='coolwarm',height=6,aspect=1,fit_reg=False)
